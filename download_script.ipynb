# %%
from ftplib import FTP
import os
import gzip
import xml.etree.ElementTree as ET
import pandas as pd

# %%
# FTP details
ftp_url = 'ftp.ncbi.nlm.nih.gov'
ftp_path = '/pubmed/baseline/'
save_path = './pubmed_data/'

# Connect to FTP
ftp = FTP(ftp_url)
ftp.login()

# Navigate to the PubMed baseline directory
ftp.cwd(ftp_path)

# List all files in the directory
files = ftp.nlst()

# %%
files
# Out:
# ['pubmed24n0002.xml.gz.md5',
#  'pubmed24n0002.xml.gz',
#  'pubmed24n0004.xml.gz.md5',
#  'pubmed24n0004.xml.gz',
#  'pubmed24n0003.xml.gz.md5',
#  'pubmed24n0003.xml.gz',
#  'pubmed24n0001.xml.gz.md5',
#  'pubmed24n0001.xml.gz',
#  'pubmed24n0006.xml.gz.md5',
#  'pubmed24n0006.xml.gz',
#  'pubmed24n0008.xml.gz.md5',
#  'pubmed24n0008.xml.gz',
#  'pubmed24n0005.xml.gz.md5',
#  'pubmed24n0005.xml.gz',
#  'pubmed24n0009.xml.gz.md5',
#  'pubmed24n0009.xml.gz',
#  'pubmed24n0007.xml.gz.md5',
#  'pubmed24n0007.xml.gz',
#  'pubmed24n0010.xml.gz.md5',
#  'pubmed24n0010.xml.gz',
#  'pubmed24n0013.xml.gz.md5',
#  'pubmed24n0013.xml.gz',
#  'pubmed24n0014.xml.gz.md5',
#  'pubmed24n0014.xml.gz',
#  'pubmed24n0011.xml.gz.md5',
#  'pubmed24n0011.xml.gz',
#  'pubmed24n0012.xml.gz.md5',
#  'pubmed24n0012.xml.gz',
#  'pubmed24n0015.xml.gz.md5',
#  'pubmed24n0015.xml.gz',
#  'pubmed24n0016.xml.gz.md5',
#  'pubmed24n0016.xml.gz',
#  'pubmed24n0018.xml.gz.md5',
#  'pubmed24n0018.xml.gz',
#  'pubmed24n0017.xml.gz.md5',
#  'pubmed24n0017.xml.gz',
#  'pubmed24n0021.xml.gz.md5',
#  'pubmed24n0021.xml.gz',
#  'pubmed24n0020.xml.gz.md5',
#  'pubmed24n0020.xml.gz',
#  'pubmed24n0019.xml.gz.md5',
#  'pubmed24n0019.xml.gz',
#  'pubmed24n0022.xml.gz.md5',
#  'pubmed24n0022.xml.gz',
#  'pubmed24n0023.xml.gz.md5',
#  'pubmed24n0023.xml.gz',
#  'pubmed24n0025.xml.gz.md5',
#  'pubmed24n0025.xml.gz',
#  'pubmed24n0024.xml.gz.md5',
#  'pubmed24n0024.xml.gz',
#  'pubmed24n0026.xml.gz.md5',
#  'pubmed24n0026.xml.gz',
#  'pubmed24n0079.xml.gz',
#  'pubmed24n0028.xml.gz',
#  'pubmed24n0028.xml.gz.md5',
#  'pubmed24n0027.xml.gz.md5',
#  'pubmed24n0027.xml.gz',
#  'pubmed24n0029.xml.gz.md5',
#  'pubmed24n0029.xml.gz',
#  'pubmed24n0030.xml.gz.md5',
#  'pubmed24n0030.xml.gz',
#  'pubmed24n0032.xml.gz.md5',
#  'pubmed24n0031.xml.gz.md5',
#  'pubmed24n0032.xml.gz',
#  'pubmed24n0031.xml.gz',
#  'pubmed24n0033.xml.gz.md5',
#  'pubmed24n0033.xml.gz',
#  'pubmed24n0034.xml.gz.md5',
#  'pubmed24n0034.xml.gz',
#  'pubmed24n0035.xml.gz.md5',
#  'pubmed24n0035.xml.gz',
#  'pubmed24n0036.xml.gz.md5',
#  'pubmed24n0036.xml.gz',
#  'pubmed24n0037.xml.gz.md5',
#  'pubmed24n0037.xml.gz',
#  'pubmed24n0038.xml.gz.md5',
#  'pubmed24n0038.xml.gz',
#  'pubmed24n0039.xml.gz.md5',
#  'pubmed24n0039.xml.gz',
#  'pubmed24n0040.xml.gz.md5',
#  'pubmed24n0040.xml.gz',
#  'pubmed24n0041.xml.gz.md5',
#  'pubmed24n0041.xml.gz',
#  'pubmed24n0042.xml.gz.md5',
#  'pubmed24n0042.xml.gz',
#  'pubmed24n0043.xml.gz.md5',
#  'pubmed24n0043.xml.gz',
#  'pubmed24n0044.xml.gz.md5',
#  'pubmed24n0044.xml.gz',
#  'pubmed24n0045.xml.gz.md5',
#  'pubmed24n0045.xml.gz',
#  'pubmed24n0046.xml.gz.md5',
#  'pubmed24n0046.xml.gz',
#  'pubmed24n0047.xml.gz.md5',
#  'pubmed24n0047.xml.gz',
#  'pubmed24n0048.xml.gz.md5',
#  'pubmed24n0048.xml.gz',
#  'pubmed24n0049.xml.gz.md5',
#  'pubmed24n0049.xml.gz',
#  'pubmed24n0050.xml.gz.md5',
#  'pubmed24n0050.xml.gz',
#  'pubmed24n0051.xml.gz.md5',
#  'pubmed24n0051.xml.gz',
#  'pubmed24n0052.xml.gz.md5',
#  'pubmed24n0052.xml.gz',
#  'pubmed24n0053.xml.gz',
#  'pubmed24n0053.xml.gz.md5',
#  'pubmed24n0054.xml.gz.md5',
#  'pubmed24n0054.xml.gz',
#  'pubmed24n0055.xml.gz.md5',
#  'pubmed24n0055.xml.gz',
#  'pubmed24n0056.xml.gz.md5',
#  'pubmed24n0056.xml.gz',
#  'pubmed24n0057.xml.gz.md5',
#  'pubmed24n0057.xml.gz',
#  'pubmed24n0058.xml.gz.md5',
#  'pubmed24n0058.xml.gz',
#  'pubmed24n0059.xml.gz.md5',
#  'pubmed24n0059.xml.gz',
#  'pubmed24n0060.xml.gz.md5',
#  'pubmed24n0060.xml.gz',
#  'pubmed24n0061.xml.gz.md5',
#  'pubmed24n0061.xml.gz',
#  'pubmed24n0062.xml.gz.md5',
#  'pubmed24n0062.xml.gz',
#  'pubmed24n0063.xml.gz.md5',
#  'pubmed24n0063.xml.gz',
#  'pubmed24n0064.xml.gz.md5',
#  'pubmed24n0064.xml.gz',
#  'pubmed24n0065.xml.gz.md5',
#  'pubmed24n0065.xml.gz',
#  'pubmed24n0066.xml.gz.md5',
#  'pubmed24n0066.xml.gz',
#  'pubmed24n0067.xml.gz.md5',
#  'pubmed24n0067.xml.gz',
#  'pubmed24n0068.xml.gz.md5',
#  'pubmed24n0068.xml.gz',
#  'pubmed24n0069.xml.gz.md5',
#  'pubmed24n0069.xml.gz',
#  'pubmed24n0070.xml.gz.md5',
#  'pubmed24n0070.xml.gz',
#  'pubmed24n0071.xml.gz.md5',
#  'pubmed24n0071.xml.gz',
#  'pubmed24n0072.xml.gz.md5',
#  'pubmed24n0072.xml.gz',
#  'pubmed24n0073.xml.gz.md5',
#  'pubmed24n0073.xml.gz',
#  'pubmed24n0074.xml.gz.md5',
#  'pubmed24n0074.xml.gz',
#  'pubmed24n0075.xml.gz.md5',
#  'pubmed24n0075.xml.gz',
#  'pubmed24n0076.xml.gz.md5',
#  'pubmed24n0076.xml.gz',
#  'pubmed24n0077.xml.gz.md5',
#  'pubmed24n0077.xml.gz',
#  'pubmed24n0078.xml.gz.md5',
#  'pubmed24n0078.xml.gz',
#  'pubmed24n0079.xml.gz.md5',
#  'pubmed24n0132.xml.gz',
#  'pubmed24n0080.xml.gz',
#  'pubmed24n0080.xml.gz.md5',
#  'pubmed24n0081.xml.gz.md5',
#  'pubmed24n0081.xml.gz',
#  'pubmed24n0082.xml.gz.md5',
#  'pubmed24n0082.xml.gz',
#  'pubmed24n0083.xml.gz.md5',
#  'pubmed24n0083.xml.gz',
#  'pubmed24n0085.xml.gz.md5',
#  'pubmed24n0085.xml.gz',
#  'pubmed24n0084.xml.gz.md5',
#  'pubmed24n0084.xml.gz',
#  'pubmed24n0086.xml.gz.md5',
#  'pubmed24n0086.xml.gz',
#  'pubmed24n0087.xml.gz.md5',
#  'pubmed24n0087.xml.gz',
#  'pubmed24n0088.xml.gz.md5',
#  'pubmed24n0088.xml.gz',
#  'pubmed24n0090.xml.gz.md5',
#  'pubmed24n0090.xml.gz',
#  'pubmed24n0089.xml.gz.md5',
#  'pubmed24n0089.xml.gz',
#  'pubmed24n0091.xml.gz.md5',
#  'pubmed24n0091.xml.gz',
#  'pubmed24n0092.xml.gz.md5',
#  'pubmed24n0093.xml.gz.md5',
#  'pubmed24n0092.xml.gz',
#  'pubmed24n0093.xml.gz',
#  'pubmed24n0094.xml.gz.md5',
#  'pubmed24n0094.xml.gz',
#  'pubmed24n0095.xml.gz.md5',
#  'pubmed24n0095.xml.gz',
#  'pubmed24n0096.xml.gz.md5',
#  'pubmed24n0096.xml.gz',
#  'pubmed24n0098.xml.gz.md5',
#  'pubmed24n0098.xml.gz',
#  'pubmed24n0097.xml.gz.md5',
#  'pubmed24n0097.xml.gz',
#  'pubmed24n0100.xml.gz.md5',
#  'pubmed24n0100.xml.gz',
#  'pubmed24n0101.xml.gz.md5',
#  'pubmed24n0101.xml.gz',
#  'pubmed24n0099.xml.gz.md5',
#  'pubmed24n0099.xml.gz',
#  'pubmed24n0102.xml.gz.md5',
#  'pubmed24n0102.xml.gz',
#  'pubmed24n0103.xml.gz.md5',
#  'pubmed24n0103.xml.gz',
#  'pubmed24n0106.xml.gz.md5',
#  'pubmed24n0106.xml.gz',
#  'pubmed24n0105.xml.gz.md5',
#  'pubmed24n0105.xml.gz',
#  'pubmed24n0104.xml.gz',
#  'pubmed24n0104.xml.gz.md5',
#  'pubmed24n0107.xml.gz.md5',
#  'pubmed24n0107.xml.gz',
#  'pubmed24n0108.xml.gz.md5',
#  'pubmed24n0108.xml.gz',
#  'pubmed24n0109.xml.gz.md5',
#  'pubmed24n0109.xml.gz',
#  'pubmed24n0110.xml.gz.md5',
#  'pubmed24n0110.xml.gz',
#  'pubmed24n0111.xml.gz.md5',
#  'pubmed24n0111.xml.gz',
#  'pubmed24n0112.xml.gz.md5',
#  'pubmed24n0112.xml.gz',
#  'pubmed24n0114.xml.gz.md5',
#  'pubmed24n0114.xml.gz',
#  'pubmed24n0113.xml.gz.md5',
#  'pubmed24n0113.xml.gz',
#  'pubmed24n0115.xml.gz.md5',
#  'pubmed24n0115.xml.gz',
#  'pubmed24n0116.xml.gz.md5',
#  'pubmed24n0116.xml.gz',
#  'pubmed24n0117.xml.gz.md5',
#  'pubmed24n0117.xml.gz',
#  'pubmed24n0118.xml.gz.md5',
#  'pubmed24n0118.xml.gz',
#  'pubmed24n0119.xml.gz.md5',
#  'pubmed24n0119.xml.gz',
#  'pubmed24n0120.xml.gz.md5',
#  'pubmed24n0120.xml.gz',
#  'pubmed24n0121.xml.gz.md5',
#  'pubmed24n0121.xml.gz',
#  'pubmed24n0122.xml.gz.md5',
#  'pubmed24n0122.xml.gz',
#  'pubmed24n0123.xml.gz.md5',
#  'pubmed24n0123.xml.gz',
#  'pubmed24n0124.xml.gz.md5',
#  'pubmed24n0124.xml.gz',
#  'pubmed24n0125.xml.gz.md5',
#  'pubmed24n0125.xml.gz',
#  'pubmed24n0126.xml.gz.md5',
#  'pubmed24n0126.xml.gz',
#  'pubmed24n0127.xml.gz.md5',
#  'pubmed24n0127.xml.gz',
#  'pubmed24n0128.xml.gz.md5',
#  'pubmed24n0128.xml.gz',
#  'pubmed24n0129.xml.gz.md5',
#  'pubmed24n0129.xml.gz',
#  'pubmed24n0130.xml.gz.md5',
#  'pubmed24n0130.xml.gz',
#  'pubmed24n0131.xml.gz.md5',
#  'pubmed24n0131.xml.gz',
#  'pubmed24n0132.xml.gz.md5',
#  'pubmed24n0185.xml.gz',
#  'pubmed24n0133.xml.gz',
#  'pubmed24n0133.xml.gz.md5',
#  'pubmed24n0134.xml.gz.md5',
#  'pubmed24n0134.xml.gz',
#  'pubmed24n0135.xml.gz.md5',
#  'pubmed24n0135.xml.gz',
#  'pubmed24n0136.xml.gz.md5',
#  'pubmed24n0136.xml.gz',
#  'pubmed24n0137.xml.gz.md5',
#  'pubmed24n0137.xml.gz',
#  'pubmed24n0138.xml.gz.md5',
#  'pubmed24n0138.xml.gz',
#  'pubmed24n0139.xml.gz.md5',
#  'pubmed24n0139.xml.gz',
#  'pubmed24n0140.xml.gz.md5',
#  'pubmed24n0140.xml.gz',
#  'pubmed24n0141.xml.gz.md5',
#  'pubmed24n0141.xml.gz',
#  'pubmed24n0142.xml.gz.md5',
#  'pubmed24n0142.xml.gz',
#  'pubmed24n0143.xml.gz.md5',
#  'pubmed24n0143.xml.gz',
#  'pubmed24n0144.xml.gz.md5',
#  'pubmed24n0144.xml.gz',
#  'pubmed24n0145.xml.gz.md5',
#  'pubmed24n0145.xml.gz',
#  'pubmed24n0146.xml.gz.md5',
#  'pubmed24n0146.xml.gz',
#  'pubmed24n0147.xml.gz.md5',
#  'pubmed24n0147.xml.gz',
#  'pubmed24n0148.xml.gz.md5',
#  'pubmed24n0148.xml.gz',
#  'pubmed24n0149.xml.gz.md5',
#  'pubmed24n0149.xml.gz',
#  'pubmed24n0150.xml.gz.md5',
#  'pubmed24n0150.xml.gz',
#  'pubmed24n0151.xml.gz.md5',
#  'pubmed24n0151.xml.gz',
#  'pubmed24n0152.xml.gz.md5',
#  'pubmed24n0152.xml.gz',
#  'pubmed24n0153.xml.gz.md5',
#  'pubmed24n0153.xml.gz',
#  'pubmed24n0154.xml.gz.md5',
#  'pubmed24n0154.xml.gz',
#  'pubmed24n0155.xml.gz.md5',
#  'pubmed24n0155.xml.gz',
#  'pubmed24n0156.xml.gz.md5',
#  'pubmed24n0156.xml.gz',
#  'pubmed24n0157.xml.gz.md5',
#  'pubmed24n0157.xml.gz',
#  'pubmed24n0158.xml.gz.md5',
#  'pubmed24n0158.xml.gz',
#  'pubmed24n0159.xml.gz',
#  'pubmed24n0159.xml.gz.md5',
#  'pubmed24n0160.xml.gz.md5',
#  'pubmed24n0160.xml.gz',
#  'pubmed24n0161.xml.gz.md5',
#  'pubmed24n0161.xml.gz',
#  'pubmed24n0162.xml.gz.md5',
#  'pubmed24n0162.xml.gz',
#  'pubmed24n0163.xml.gz.md5',
#  'pubmed24n0163.xml.gz',
#  'pubmed24n0164.xml.gz.md5',
#  'pubmed24n0164.xml.gz',
#  'pubmed24n0165.xml.gz.md5',
#  'pubmed24n0165.xml.gz',
#  'pubmed24n0166.xml.gz.md5',
#  'pubmed24n0166.xml.gz',
#  'pubmed24n0167.xml.gz.md5',
#  'pubmed24n0167.xml.gz',
#  'pubmed24n0168.xml.gz.md5',
#  'pubmed24n0168.xml.gz',
#  'pubmed24n0169.xml.gz.md5',
#  'pubmed24n0169.xml.gz',
#  'pubmed24n0170.xml.gz.md5',
#  'pubmed24n0170.xml.gz',
#  'pubmed24n0171.xml.gz.md5',
#  'pubmed24n0171.xml.gz',
#  'pubmed24n0172.xml.gz.md5',
#  'pubmed24n0172.xml.gz',
#  'pubmed24n0173.xml.gz.md5',
#  'pubmed24n0173.xml.gz',
#  'pubmed24n0174.xml.gz.md5',
#  'pubmed24n0174.xml.gz',
#  'pubmed24n0175.xml.gz.md5',
#  'pubmed24n0175.xml.gz',
#  'pubmed24n0176.xml.gz.md5',
#  'pubmed24n0176.xml.gz',
#  'pubmed24n0177.xml.gz.md5',
#  'pubmed24n0177.xml.gz',
#  'pubmed24n0178.xml.gz.md5',
#  'pubmed24n0178.xml.gz',
#  'pubmed24n0179.xml.gz.md5',
#  'pubmed24n0179.xml.gz',
#  'pubmed24n0180.xml.gz.md5',
#  'pubmed24n0180.xml.gz',
#  'pubmed24n0181.xml.gz.md5',
#  'pubmed24n0181.xml.gz',
#  'pubmed24n0182.xml.gz.md5',
#  'pubmed24n0182.xml.gz',
#  'pubmed24n0183.xml.gz.md5',
#  'pubmed24n0183.xml.gz',
#  'pubmed24n0184.xml.gz.md5',
#  'pubmed24n0184.xml.gz',
#  'pubmed24n0185.xml.gz.md5',
#  'pubmed24n0238.xml.gz',
#  'pubmed24n0186.xml.gz',
#  'pubmed24n0186.xml.gz.md5',
#  'pubmed24n0187.xml.gz.md5',
#  'pubmed24n0187.xml.gz',
#  'pubmed24n0188.xml.gz.md5',
#  'pubmed24n0188.xml.gz',
#  'pubmed24n0189.xml.gz.md5',
#  'pubmed24n0189.xml.gz',
#  'pubmed24n0190.xml.gz.md5',
#  'pubmed24n0190.xml.gz',
#  'pubmed24n0191.xml.gz.md5',
#  'pubmed24n0191.xml.gz',
#  'pubmed24n0192.xml.gz.md5',
#  'pubmed24n0192.xml.gz',
#  'pubmed24n0193.xml.gz.md5',
#  'pubmed24n0193.xml.gz',
#  'pubmed24n0194.xml.gz.md5',
#  'pubmed24n0194.xml.gz',
#  'pubmed24n0195.xml.gz.md5',
#  'pubmed24n0195.xml.gz',
#  'pubmed24n0196.xml.gz.md5',
#  'pubmed24n0196.xml.gz',
#  'pubmed24n0197.xml.gz.md5',
#  'pubmed24n0197.xml.gz',
#  'pubmed24n0198.xml.gz.md5',
#  'pubmed24n0198.xml.gz',
#  'pubmed24n0199.xml.gz.md5',
#  'pubmed24n0199.xml.gz',
#  'pubmed24n0200.xml.gz.md5',
#  'pubmed24n0200.xml.gz',
#  'pubmed24n0201.xml.gz.md5',
#  'pubmed24n0201.xml.gz',
#  'pubmed24n0202.xml.gz.md5',
#  'pubmed24n0202.xml.gz',
#  'pubmed24n0203.xml.gz.md5',
#  'pubmed24n0203.xml.gz',
#  'pubmed24n0204.xml.gz.md5',
#  'pubmed24n0204.xml.gz',
#  'pubmed24n0205.xml.gz.md5',
#  'pubmed24n0205.xml.gz',
#  'pubmed24n0206.xml.gz.md5',
#  'pubmed24n0206.xml.gz',
#  'pubmed24n0207.xml.gz.md5',
#  'pubmed24n0207.xml.gz',
#  'pubmed24n0208.xml.gz.md5',
#  'pubmed24n0208.xml.gz',
#  'pubmed24n0209.xml.gz.md5',
#  'pubmed24n0209.xml.gz',
#  'pubmed24n0210.xml.gz.md5',
#  'pubmed24n0210.xml.gz',
#  'pubmed24n0211.xml.gz.md5',
#  'pubmed24n0211.xml.gz',
#  'pubmed24n0212.xml.gz',
#  'pubmed24n0212.xml.gz.md5',
#  'pubmed24n0213.xml.gz.md5',
#  'pubmed24n0213.xml.gz',
#  'pubmed24n0215.xml.gz.md5',
#  'pubmed24n0215.xml.gz',
#  'pubmed24n0214.xml.gz.md5',
#  'pubmed24n0214.xml.gz',
#  'pubmed24n0216.xml.gz.md5',
#  'pubmed24n0216.xml.gz',
#  'pubmed24n0217.xml.gz.md5',
#  'pubmed24n0217.xml.gz',
#  'pubmed24n0218.xml.gz.md5',
#  'pubmed24n0218.xml.gz',
#  'pubmed24n0219.xml.gz.md5',
#  'pubmed24n0219.xml.gz',
#  'pubmed24n0220.xml.gz.md5',
#  'pubmed24n0220.xml.gz',
#  'pubmed24n0221.xml.gz.md5',
#  'pubmed24n0221.xml.gz',
#  'pubmed24n0222.xml.gz.md5',
#  'pubmed24n0222.xml.gz',
#  'pubmed24n0223.xml.gz.md5',
#  'pubmed24n0223.xml.gz',
#  'pubmed24n0224.xml.gz.md5',
#  'pubmed24n0224.xml.gz',
#  'pubmed24n0225.xml.gz.md5',
#  'pubmed24n0225.xml.gz',
#  'pubmed24n0226.xml.gz.md5',
#  'pubmed24n0226.xml.gz',
#  'pubmed24n0227.xml.gz.md5',
#  'pubmed24n0227.xml.gz',
#  'pubmed24n0228.xml.gz.md5',
#  'pubmed24n0228.xml.gz',
#  'pubmed24n0229.xml.gz.md5',
#  'pubmed24n0229.xml.gz',
#  'pubmed24n0230.xml.gz.md5',
#  'pubmed24n0230.xml.gz',
#  'pubmed24n0231.xml.gz.md5',
#  'pubmed24n0231.xml.gz',
#  'pubmed24n0232.xml.gz.md5',
#  'pubmed24n0232.xml.gz',
#  'pubmed24n0233.xml.gz.md5',
#  'pubmed24n0233.xml.gz',
#  'pubmed24n0234.xml.gz.md5',
#  'pubmed24n0234.xml.gz',
#  'pubmed24n0235.xml.gz.md5',
#  'pubmed24n0235.xml.gz',
#  'pubmed24n0236.xml.gz.md5',
#  'pubmed24n0236.xml.gz',
#  'pubmed24n0237.xml.gz.md5',
#  'pubmed24n0237.xml.gz',
#  'pubmed24n0238.xml.gz.md5',
#  'pubmed24n0291.xml.gz',
#  'pubmed24n0239.xml.gz',
#  'pubmed24n0239.xml.gz.md5',
#  'pubmed24n0240.xml.gz.md5',
#  'pubmed24n0240.xml.gz',
#  'pubmed24n0241.xml.gz.md5',
#  'pubmed24n0241.xml.gz',
#  'pubmed24n0242.xml.gz.md5',
#  'pubmed24n0242.xml.gz',
#  'pubmed24n0243.xml.gz.md5',
#  'pubmed24n0243.xml.gz',
#  'pubmed24n0244.xml.gz.md5',
#  'pubmed24n0244.xml.gz',
#  'pubmed24n0245.xml.gz.md5',
#  'pubmed24n0245.xml.gz',
#  'pubmed24n0246.xml.gz.md5',
#  'pubmed24n0246.xml.gz',
#  'pubmed24n0247.xml.gz.md5',
#  'pubmed24n0247.xml.gz',
#  'pubmed24n0248.xml.gz.md5',
#  'pubmed24n0248.xml.gz',
#  'pubmed24n0249.xml.gz.md5',
#  'pubmed24n0249.xml.gz',
#  'pubmed24n0250.xml.gz.md5',
#  'pubmed24n0250.xml.gz',
#  'pubmed24n0251.xml.gz.md5',
#  'pubmed24n0251.xml.gz',
#  'pubmed24n0252.xml.gz.md5',
#  'pubmed24n0252.xml.gz',
#  'pubmed24n0253.xml.gz.md5',
#  'pubmed24n0253.xml.gz',
#  'pubmed24n0254.xml.gz.md5',
#  'pubmed24n0254.xml.gz',
#  'pubmed24n0255.xml.gz.md5',
#  'pubmed24n0255.xml.gz',
#  'pubmed24n0256.xml.gz.md5',
#  'pubmed24n0256.xml.gz',
#  'pubmed24n0257.xml.gz.md5',
#  'pubmed24n0257.xml.gz',
#  'pubmed24n0258.xml.gz.md5',
#  'pubmed24n0258.xml.gz',
#  'pubmed24n0259.xml.gz.md5',
#  'pubmed24n0259.xml.gz',
#  'pubmed24n0260.xml.gz.md5',
#  'pubmed24n0260.xml.gz',
#  'pubmed24n0261.xml.gz.md5',
#  'pubmed24n0261.xml.gz',
#  'pubmed24n0262.xml.gz.md5',
#  'pubmed24n0262.xml.gz',
#  'pubmed24n0263.xml.gz.md5',
#  'pubmed24n0263.xml.gz',
#  'pubmed24n0264.xml.gz.md5',
#  'pubmed24n0264.xml.gz',
#  'pubmed24n0265.xml.gz',
#  'pubmed24n0265.xml.gz.md5',
#  'pubmed24n0266.xml.gz.md5',
#  'pubmed24n0266.xml.gz',
#  'pubmed24n0267.xml.gz.md5',
#  'pubmed24n0267.xml.gz',
#  'pubmed24n0268.xml.gz.md5',
#  'pubmed24n0268.xml.gz',
#  'pubmed24n0269.xml.gz.md5',
#  'pubmed24n0269.xml.gz',
#  'pubmed24n0270.xml.gz.md5',
#  'pubmed24n0270.xml.gz',
#  'pubmed24n0271.xml.gz.md5',
#  'pubmed24n0271.xml.gz',
#  'pubmed24n0272.xml.gz.md5',
#  'pubmed24n0272.xml.gz',
#  'pubmed24n0273.xml.gz.md5',
#  'pubmed24n0273.xml.gz',
#  'pubmed24n0274.xml.gz.md5',
#  'pubmed24n0274.xml.gz',
#  'pubmed24n0275.xml.gz.md5',
#  'pubmed24n0275.xml.gz',
#  'pubmed24n0276.xml.gz.md5',
#  'pubmed24n0276.xml.gz',
#  'pubmed24n0277.xml.gz.md5',
#  'pubmed24n0277.xml.gz',
#  'pubmed24n0278.xml.gz.md5',
#  'pubmed24n0278.xml.gz',
#  'pubmed24n0279.xml.gz.md5',
#  'pubmed24n0279.xml.gz',
#  'pubmed24n0281.xml.gz.md5',
#  'pubmed24n0281.xml.gz',
#  'pubmed24n0280.xml.gz.md5',
#  'pubmed24n0280.xml.gz',
#  'pubmed24n0282.xml.gz.md5',
#  'pubmed24n0282.xml.gz',
#  'pubmed24n0283.xml.gz.md5',
#  'pubmed24n0283.xml.gz',
#  'pubmed24n0284.xml.gz.md5',
#  'pubmed24n0284.xml.gz',
#  'pubmed24n0285.xml.gz.md5',
#  'pubmed24n0285.xml.gz',
#  'pubmed24n0286.xml.gz.md5',
#  'pubmed24n0286.xml.gz',
#  'pubmed24n0287.xml.gz.md5',
#  'pubmed24n0287.xml.gz',
#  'pubmed24n0289.xml.gz.md5',
#  'pubmed24n0289.xml.gz',
#  'pubmed24n0288.xml.gz.md5',
#  'pubmed24n0288.xml.gz',
#  'pubmed24n0290.xml.gz.md5',
#  'pubmed24n0290.xml.gz',
#  'pubmed24n0291.xml.gz.md5',
#  'pubmed24n0344.xml.gz',
#  'pubmed24n0292.xml.gz',
#  'pubmed24n0292.xml.gz.md5',
#  'pubmed24n0293.xml.gz.md5',
#  'pubmed24n0293.xml.gz',
#  'pubmed24n0294.xml.gz.md5',
#  'pubmed24n0294.xml.gz',
#  'pubmed24n0295.xml.gz.md5',
#  'pubmed24n0295.xml.gz',
#  'pubmed24n0297.xml.gz.md5',
#  'pubmed24n0297.xml.gz',
#  'pubmed24n0296.xml.gz.md5',
#  'pubmed24n0296.xml.gz',
#  'pubmed24n0298.xml.gz.md5',
#  'pubmed24n0298.xml.gz',
#  'pubmed24n0299.xml.gz.md5',
#  'pubmed24n0299.xml.gz',
#  'pubmed24n0301.xml.gz.md5',
#  'pubmed24n0301.xml.gz',
#  'pubmed24n0300.xml.gz.md5',
#  'pubmed24n0300.xml.gz',
#  'pubmed24n0302.xml.gz.md5',
#  'pubmed24n0302.xml.gz',
#  'pubmed24n0303.xml.gz.md5',
#  'pubmed24n0303.xml.gz',
#  'pubmed24n0305.xml.gz.md5',
#  'pubmed24n0305.xml.gz',
#  'pubmed24n0304.xml.gz.md5',
#  'pubmed24n0304.xml.gz',
#  'pubmed24n0306.xml.gz.md5',
#  'pubmed24n0306.xml.gz',
#  'pubmed24n0307.xml.gz.md5',
#  'pubmed24n0307.xml.gz',
#  'pubmed24n0308.xml.gz.md5',
#  'pubmed24n0308.xml.gz',
#  'pubmed24n0309.xml.gz.md5',
#  'pubmed24n0309.xml.gz',
#  'pubmed24n0310.xml.gz.md5',
#  'pubmed24n0310.xml.gz',
#  'pubmed24n0311.xml.gz.md5',
#  'pubmed24n0311.xml.gz',
#  'pubmed24n0312.xml.gz.md5',
#  'pubmed24n0312.xml.gz',
#  'pubmed24n0313.xml.gz.md5',
#  'pubmed24n0313.xml.gz',
#  'pubmed24n0314.xml.gz.md5',
#  'pubmed24n0314.xml.gz',
#  'pubmed24n0315.xml.gz.md5',
#  'pubmed24n0315.xml.gz',
#  'pubmed24n0316.xml.gz.md5',
#  'pubmed24n0316.xml.gz',
#  'pubmed24n0317.xml.gz.md5',
#  'pubmed24n0317.xml.gz',
#  'pubmed24n0318.xml.gz',
#  'pubmed24n0318.xml.gz.md5',
#  'pubmed24n0319.xml.gz.md5',
#  'pubmed24n0319.xml.gz',
#  'pubmed24n0320.xml.gz.md5',
#  'pubmed24n0320.xml.gz',
#  'pubmed24n0321.xml.gz.md5',
#  'pubmed24n0321.xml.gz',
#  'pubmed24n0322.xml.gz.md5',
#  'pubmed24n0322.xml.gz',
#  'pubmed24n0323.xml.gz.md5',
#  'pubmed24n0323.xml.gz',
#  'pubmed24n0324.xml.gz.md5',
#  'pubmed24n0324.xml.gz',
#  'pubmed24n0326.xml.gz.md5',
#  'pubmed24n0326.xml.gz',
#  'pubmed24n0325.xml.gz.md5',
#  'pubmed24n0325.xml.gz',
#  'pubmed24n0327.xml.gz.md5',
#  'pubmed24n0327.xml.gz',
#  'pubmed24n0328.xml.gz.md5',
#  'pubmed24n0328.xml.gz',
#  'pubmed24n0330.xml.gz.md5',
#  'pubmed24n0330.xml.gz',
#  'pubmed24n0329.xml.gz.md5',
#  'pubmed24n0329.xml.gz',
#  'pubmed24n0331.xml.gz.md5',
#  'pubmed24n0331.xml.gz',
#  'pubmed24n0332.xml.gz.md5',
#  'pubmed24n0332.xml.gz',
#  'pubmed24n0333.xml.gz.md5',
#  'pubmed24n0333.xml.gz',
#  'pubmed24n0334.xml.gz.md5',
#  'pubmed24n0334.xml.gz',
#  'pubmed24n0335.xml.gz.md5',
#  'pubmed24n0335.xml.gz',
#  'pubmed24n0336.xml.gz.md5',
#  'pubmed24n0336.xml.gz',
#  'pubmed24n0337.xml.gz.md5',
#  'pubmed24n0337.xml.gz',
#  'pubmed24n0338.xml.gz.md5',
#  'pubmed24n0338.xml.gz',
#  'pubmed24n0341.xml.gz.md5',
#  'pubmed24n0341.xml.gz',
#  'pubmed24n0340.xml.gz.md5',
#  'pubmed24n0340.xml.gz',
#  'pubmed24n0339.xml.gz.md5',
#  'pubmed24n0339.xml.gz',
#  'pubmed24n0342.xml.gz.md5',
#  'pubmed24n0342.xml.gz',
#  'pubmed24n0343.xml.gz.md5',
#  'pubmed24n0343.xml.gz',
#  'pubmed24n0344.xml.gz.md5',
#  'pubmed24n0397.xml.gz',
#  'pubmed24n0345.xml.gz',
#  'pubmed24n0345.xml.gz.md5',
#  'pubmed24n0346.xml.gz',
#  'pubmed24n0346.xml.gz.md5',
#  'pubmed24n0347.xml.gz.md5',
#  'pubmed24n0347.xml.gz',
#  'pubmed24n0348.xml.gz.md5',
#  'pubmed24n0348.xml.gz',
#  'pubmed24n0349.xml.gz.md5',
#  'pubmed24n0349.xml.gz',
#  'pubmed24n0351.xml.gz.md5',
#  'pubmed24n0351.xml.gz',
#  'pubmed24n0352.xml.gz.md5',
#  'pubmed24n0352.xml.gz',
#  'pubmed24n0350.xml.gz.md5',
#  'pubmed24n0350.xml.gz',
#  'pubmed24n0353.xml.gz.md5',
#  'pubmed24n0353.xml.gz',
#  'pubmed24n0355.xml.gz.md5',
#  'pubmed24n0354.xml.gz.md5',
#  'pubmed24n0355.xml.gz',
#  'pubmed24n0354.xml.gz',
#  'pubmed24n0356.xml.gz.md5',
#  'pubmed24n0356.xml.gz',
#  'pubmed24n0357.xml.gz.md5',
#  'pubmed24n0357.xml.gz',
#  'pubmed24n0359.xml.gz.md5',
#  'pubmed24n0359.xml.gz',
#  'pubmed24n0358.xml.gz.md5',
#  'pubmed24n0358.xml.gz',
#  'pubmed24n0360.xml.gz.md5',
#  'pubmed24n0360.xml.gz',
#  'pubmed24n0361.xml.gz.md5',
#  'pubmed24n0361.xml.gz',
#  'pubmed24n0362.xml.gz.md5',
#  'pubmed24n0362.xml.gz',
#  'pubmed24n0365.xml.gz.md5',
#  'pubmed24n0365.xml.gz',
#  'pubmed24n0363.xml.gz.md5',
#  'pubmed24n0363.xml.gz',
#  'pubmed24n0364.xml.gz.md5',
#  'pubmed24n0364.xml.gz',
#  'pubmed24n0366.xml.gz.md5',
#  'pubmed24n0366.xml.gz',
#  'pubmed24n0368.xml.gz.md5',
#  'pubmed24n0368.xml.gz',
#  'pubmed24n0367.xml.gz.md5',
#  'pubmed24n0367.xml.gz',
#  'pubmed24n0369.xml.gz.md5',
#  'pubmed24n0369.xml.gz',
#  'pubmed24n0370.xml.gz.md5',
#  'pubmed24n0370.xml.gz',
#  'pubmed24n0371.xml.gz',
#  'pubmed24n0371.xml.gz.md5',
#  'pubmed24n0372.xml.gz.md5',
#  'pubmed24n0372.xml.gz',
#  'pubmed24n0373.xml.gz.md5',
#  'pubmed24n0373.xml.gz',
#  'pubmed24n0374.xml.gz.md5',
#  'pubmed24n0374.xml.gz',
#  'pubmed24n0375.xml.gz.md5',
#  'pubmed24n0375.xml.gz',
#  'pubmed24n0376.xml.gz.md5',
#  'pubmed24n0376.xml.gz',
#  'pubmed24n0377.xml.gz.md5',
#  'pubmed24n0377.xml.gz',
#  'pubmed24n0378.xml.gz.md5',
#  'pubmed24n0378.xml.gz',
#  'pubmed24n0379.xml.gz.md5',
#  'pubmed24n0379.xml.gz',
#  'pubmed24n0380.xml.gz.md5',
#  'pubmed24n0380.xml.gz',
#  'pubmed24n0381.xml.gz.md5',
#  'pubmed24n0381.xml.gz',
#  'pubmed24n0382.xml.gz.md5',
#  'pubmed24n0382.xml.gz',
#  'pubmed24n0384.xml.gz.md5',
#  'pubmed24n0384.xml.gz',
#  'pubmed24n0383.xml.gz.md5',
#  'pubmed24n0383.xml.gz',
#  'pubmed24n0385.xml.gz.md5',
#  'pubmed24n0385.xml.gz',
#  'pubmed24n0386.xml.gz.md5',
#  'pubmed24n0386.xml.gz',
#  'pubmed24n0387.xml.gz.md5',
#  'pubmed24n0387.xml.gz',
#  'pubmed24n0388.xml.gz.md5',
#  'pubmed24n0388.xml.gz',
#  'pubmed24n0389.xml.gz.md5',
#  'pubmed24n0389.xml.gz',
#  'pubmed24n0390.xml.gz.md5',
#  'pubmed24n0390.xml.gz',
#  'pubmed24n0391.xml.gz.md5',
#  'pubmed24n0391.xml.gz',
#  'pubmed24n0392.xml.gz.md5',
#  'pubmed24n0392.xml.gz',
#  'pubmed24n0393.xml.gz.md5',
#  'pubmed24n0393.xml.gz',
#  'pubmed24n0394.xml.gz.md5',
#  'pubmed24n0394.xml.gz',
#  'pubmed24n0395.xml.gz.md5',
#  'pubmed24n0395.xml.gz',
#  'pubmed24n0396.xml.gz.md5',
#  'pubmed24n0396.xml.gz',
#  'pubmed24n0397.xml.gz.md5',
#  'pubmed24n0450.xml.gz',
#  'pubmed24n0398.xml.gz',
#  'pubmed24n0398.xml.gz.md5',
#  'pubmed24n0399.xml.gz.md5',
#  'pubmed24n0399.xml.gz',
#  'pubmed24n0401.xml.gz.md5',
#  'pubmed24n0401.xml.gz',
#  'pubmed24n0400.xml.gz.md5',
#  'pubmed24n0400.xml.gz',
#  'pubmed24n0402.xml.gz.md5',
#  'pubmed24n0402.xml.gz',
#  'pubmed24n0403.xml.gz.md5',
#  'pubmed24n0403.xml.gz',
#  'pubmed24n0404.xml.gz.md5',
#  'pubmed24n0404.xml.gz',
#  'pubmed24n0405.xml.gz.md5',
#  'pubmed24n0405.xml.gz',
#  'pubmed24n0406.xml.gz.md5',
#  'pubmed24n0406.xml.gz',
#  'pubmed24n0407.xml.gz.md5',
#  'pubmed24n0407.xml.gz',
#  'pubmed24n0408.xml.gz.md5',
#  'pubmed24n0408.xml.gz',
#  'pubmed24n0409.xml.gz.md5',
#  'pubmed24n0409.xml.gz',
#  'pubmed24n0410.xml.gz.md5',
#  'pubmed24n0410.xml.gz',
#  'pubmed24n0411.xml.gz.md5',
#  'pubmed24n0411.xml.gz',
#  'pubmed24n0412.xml.gz.md5',
#  'pubmed24n0412.xml.gz',
#  'pubmed24n0413.xml.gz.md5',
#  'pubmed24n0413.xml.gz',
#  'pubmed24n0414.xml.gz.md5',
#  'pubmed24n0414.xml.gz',
#  'pubmed24n0415.xml.gz.md5',
#  'pubmed24n0415.xml.gz',
#  'pubmed24n0416.xml.gz.md5',
#  'pubmed24n0416.xml.gz',
#  'pubmed24n0417.xml.gz.md5',
#  'pubmed24n0417.xml.gz',
#  'pubmed24n0418.xml.gz.md5',
#  'pubmed24n0418.xml.gz',
#  'pubmed24n0419.xml.gz.md5',
#  'pubmed24n0419.xml.gz',
#  'pubmed24n0420.xml.gz.md5',
#  'pubmed24n0420.xml.gz',
#  'pubmed24n0421.xml.gz.md5',
#  'pubmed24n0421.xml.gz',
#  'pubmed24n0422.xml.gz.md5',
#  'pubmed24n0422.xml.gz',
#  'pubmed24n0424.xml.gz.md5',
#  'pubmed24n0424.xml.gz',
#  'pubmed24n0425.xml.gz',
#  'pubmed24n0425.xml.gz.md5',
#  'pubmed24n0423.xml.gz.md5',
#  'pubmed24n0423.xml.gz',
#  'pubmed24n0426.xml.gz.md5',
#  'pubmed24n0426.xml.gz',
#  'pubmed24n0427.xml.gz.md5',
#  'pubmed24n0427.xml.gz',
#  'pubmed24n0428.xml.gz.md5',
#  'pubmed24n0428.xml.gz',
#  'pubmed24n0429.xml.gz.md5',
#  'pubmed24n0429.xml.gz',
#  'pubmed24n0430.xml.gz.md5',
#  'pubmed24n0430.xml.gz',
#  'pubmed24n0431.xml.gz.md5',
#  'pubmed24n0431.xml.gz',
#  'pubmed24n0432.xml.gz.md5',
#  'pubmed24n0432.xml.gz',
#  'pubmed24n0433.xml.gz.md5',
#  'pubmed24n0433.xml.gz',
#  'pubmed24n0434.xml.gz.md5',
#  'pubmed24n0434.xml.gz',
#  'pubmed24n0435.xml.gz.md5',
#  'pubmed24n0435.xml.gz',
#  'pubmed24n0436.xml.gz.md5',
#  'pubmed24n0436.xml.gz',
#  'pubmed24n0437.xml.gz.md5',
#  'pubmed24n0437.xml.gz',
#  'pubmed24n0438.xml.gz.md5',
#  'pubmed24n0438.xml.gz',
#  'pubmed24n0439.xml.gz.md5',
#  'pubmed24n0439.xml.gz',
#  'pubmed24n0440.xml.gz.md5',
#  'pubmed24n0440.xml.gz',
#  'pubmed24n0441.xml.gz.md5',
#  'pubmed24n0441.xml.gz',
#  'pubmed24n0442.xml.gz.md5',
#  'pubmed24n0442.xml.gz',
#  'pubmed24n0445.xml.gz.md5',
#  'pubmed24n0445.xml.gz',
#  'pubmed24n0443.xml.gz.md5',
#  'pubmed24n0443.xml.gz',
#  'pubmed24n0444.xml.gz.md5',
#  'pubmed24n0444.xml.gz',
#  'pubmed24n0446.xml.gz.md5',
#  'pubmed24n0446.xml.gz',
#  'pubmed24n0447.xml.gz.md5',
#  'pubmed24n0447.xml.gz',
#  'pubmed24n0448.xml.gz.md5',
#  'pubmed24n0448.xml.gz',
#  'pubmed24n0449.xml.gz.md5',
#  'pubmed24n0449.xml.gz',
#  'pubmed24n0450.xml.gz.md5',
#  'pubmed24n0502.xml.gz',
#  'pubmed24n0451.xml.gz',
#  'pubmed24n0451.xml.gz.md5',
#  'pubmed24n0453.xml.gz.md5',
#  'pubmed24n0453.xml.gz',
#  'pubmed24n0452.xml.gz.md5',
#  'pubmed24n0452.xml.gz',
#  'pubmed24n0454.xml.gz.md5',
#  'pubmed24n0454.xml.gz',
#  'pubmed24n0455.xml.gz.md5',
#  'pubmed24n0455.xml.gz',
#  'pubmed24n0456.xml.gz.md5',
#  'pubmed24n0456.xml.gz',
#  'pubmed24n0457.xml.gz.md5',
#  'pubmed24n0457.xml.gz',
#  'pubmed24n0458.xml.gz.md5',
#  'pubmed24n0458.xml.gz',
#  'pubmed24n0459.xml.gz.md5',
#  'pubmed24n0459.xml.gz',
#  'pubmed24n0460.xml.gz.md5',
#  'pubmed24n0460.xml.gz',
#  'pubmed24n0461.xml.gz.md5',
#  'pubmed24n0461.xml.gz',
#  'pubmed24n0462.xml.gz.md5',
#  'pubmed24n0462.xml.gz',
#  'pubmed24n0463.xml.gz.md5',
#  'pubmed24n0463.xml.gz',
#  'pubmed24n0464.xml.gz.md5',
#  'pubmed24n0464.xml.gz',
#  'pubmed24n0465.xml.gz.md5',
#  'pubmed24n0465.xml.gz',
#  'pubmed24n0466.xml.gz.md5',
#  'pubmed24n0466.xml.gz',
#  'pubmed24n0467.xml.gz.md5',
#  'pubmed24n0467.xml.gz',
#  'pubmed24n0468.xml.gz.md5',
#  'pubmed24n0468.xml.gz',
#  'pubmed24n0469.xml.gz.md5',
#  'pubmed24n0469.xml.gz',
#  'pubmed24n0470.xml.gz.md5',
#  'pubmed24n0470.xml.gz',
#  'pubmed24n0471.xml.gz.md5',
#  'pubmed24n0471.xml.gz',
#  'pubmed24n0472.xml.gz.md5',
#  'pubmed24n0472.xml.gz',
#  'pubmed24n0473.xml.gz.md5',
#  'pubmed24n0473.xml.gz',
#  'pubmed24n0474.xml.gz.md5',
#  'pubmed24n0474.xml.gz',
#  'pubmed24n0475.xml.gz.md5',
#  'pubmed24n0475.xml.gz',
#  'pubmed24n0476.xml.gz.md5',
#  'pubmed24n0476.xml.gz',
#  'pubmed24n0477.xml.gz',
#  'pubmed24n0477.xml.gz.md5',
#  'pubmed24n0478.xml.gz.md5',
#  'pubmed24n0478.xml.gz',
#  'pubmed24n0479.xml.gz.md5',
#  'pubmed24n0479.xml.gz',
#  'pubmed24n0481.xml.gz.md5',
#  'pubmed24n0481.xml.gz',
#  'pubmed24n0480.xml.gz.md5',
#  'pubmed24n0480.xml.gz',
#  'pubmed24n0482.xml.gz.md5',
#  'pubmed24n0482.xml.gz',
#  'pubmed24n0483.xml.gz.md5',
#  'pubmed24n0483.xml.gz',
#  'pubmed24n0484.xml.gz.md5',
#  'pubmed24n0484.xml.gz',
#  'pubmed24n0485.xml.gz.md5',
#  'pubmed24n0485.xml.gz',
#  'pubmed24n0486.xml.gz.md5',
#  'pubmed24n0486.xml.gz',
#  'pubmed24n0487.xml.gz.md5',
#  'pubmed24n0487.xml.gz',
#  'pubmed24n0488.xml.gz.md5',
#  'pubmed24n0488.xml.gz',
#  'pubmed24n0489.xml.gz.md5',
#  'pubmed24n0489.xml.gz',
#  'pubmed24n0490.xml.gz.md5',
#  'pubmed24n0490.xml.gz',
#  'pubmed24n0491.xml.gz.md5',
#  'pubmed24n0491.xml.gz',
#  'pubmed24n0492.xml.gz.md5',
#  'pubmed24n0492.xml.gz',
#  'pubmed24n0493.xml.gz.md5',
#  'pubmed24n0493.xml.gz',
#  'pubmed24n0494.xml.gz.md5',
#  'pubmed24n0494.xml.gz',
#  'pubmed24n0495.xml.gz.md5',
#  'pubmed24n0495.xml.gz',
#  'pubmed24n0496.xml.gz.md5',
#  'pubmed24n0496.xml.gz',
#  'pubmed24n0497.xml.gz.md5',
#  'pubmed24n0497.xml.gz',
#  'pubmed24n0498.xml.gz.md5',
#  'pubmed24n0498.xml.gz',
#  'pubmed24n0499.xml.gz.md5',
#  'pubmed24n0499.xml.gz',
#  'pubmed24n0500.xml.gz.md5',
#  ...]

# %%
# Create a directory to save downloaded files
if not os.path.exists(save_path):
    os.makedirs(save_path)

# Download and extract gzip files
for file in files:
    if file.endswith('.gz'):
        local_file = os.path.join(save_path, file)
        with open(local_file, 'wb') as f:
            ftp.retrbinary('RETR ' + file, f.write)
        # Extract the gzip file
        with gzip.open(local_file, 'rb') as f_in:
            with open(local_file[:-3], 'wb') as f_out:
                f_out.write(f_in.read())

# Parse XML files and store required data
data = []
for file in os.listdir(save_path):
    if file.endswith('.xml'):
        tree = ET.parse(os.path.join(save_path, file))
        root = tree.getroot()
        for article in root.findall('.//PubmedArticle'):
            pub_id = article.find('.//PMID').text
            pub_date = article.find('.//ArticleDate')
            pub_date = pub_date.find('.//Year').text if pub_date is not None else None
            abstract = article.find('.//AbstractText')
            abstract_text = abstract.text if abstract is not None else None
            data.append({'ID': pub_id, 'Date': pub_date, 'Abstract': abstract_text})

# Convert data to a pandas DataFrame
df = pd.DataFrame(data)

# Save to a Parquet file
df.to_parquet("pubmed_baseline_data.parquet", index=False)

# Close FTP connection
ftp.quit()
